# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7]
y = [12, 20, 25, 22, 20, 25, 30]

plt.plot(x, y); plt.show()
plt.bar(x, y); plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5, 6, 7]
y = [12, 20, 25, 22, 20, 25, 30]


plt.plot(x, y, 'r'); plt.bar(x, y)
# Out:
# <BarContainer object of 7 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 2*np.pi, .05)
y = np.sin(x)

plt.plot(x, y); plt.grid(True)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([[12, 14, 40], [20, 25, 43], [25, 30, 41], [22, 20, 35], [20, 30 ,42], [25, 30, 35], [30, 35, 38]])

plt.plot(x, y); plt.title('Amount of sales')
plt.xlabel('days'); plt.ylabel('amount (unit: zkG)')
plt.legend(['apple', 'plum', 'strowberry'], loc = 'lower right')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([[12, 14, 40], [20, 25, 43], [25, 30, 41], [22, 20, 35], [20, 30 ,42], [25, 30, 35], [30, 35, 38]])

plt.plot(x, y[:, 0], 'g*-', linewidth=1.5, markersize=8)
plt.plot(x, y[:, 1], 'ro--', linewidth=2.0, markersize=7)
plt.plot(x, y[:, 2], 'b+:', linewidth=1.0, markersize=6)

plt.title('Amount of sales'); plt.xlabel('days'); plt.ylabel('amount (unit: Kg)')
plt.legend(['apple', 'plum', 'strawberry'], loc = 'lower right'); plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([[12, 14, 40], [20, 25, 43], [25, 30, 41], [22, 20, 35], [20, 30 ,42], [25, 30, 35], [30, 35, 38]])

plt.plot(x, y[:, 0], 'k*-', linewidth=1.5, markersize=8)
plt.plot(x, y[:, 1], 'ko--', linewidth=2.0, markersize=7)
plt.plot(x, y[:, 2], 'k+:', linewidth=1.0, markersize=6)

plt.title('Amount of sales'); plt.xlabel('days'); plt.ylabel('amount (unit: Kg)')
plt.legend(['apple', 'plum', 'strawberry'], loc = 'lower right'); plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([[12, 14, 40], [20, 25, 43], [25, 30, 41], [22, 20, 35], [20, 30 ,42], [25, 30, 35], [30, 35, 38]])

plt.figure(figsize=(15, 3)); plt.suptitle('Amount of sales for 3 items')
plt.subplot(1, 3, 1); plt.plot(x, y[:, 0], 'g*-', linewidth=1.5, markersize=8)
plt.xlabel('days'); plt.ylabel('amount (unit: Kg)'); plt.legend(['apple'])

plt.subplot(1, 3, 2); plt.plot(x, y[:, 1], 'ro--', linewidth=1.5, markersize=8)
plt.xlabel('days'); plt.ylabel('amount (unit: Kg)'); plt.legend(['plum'])

plt.subplot(1, 3, 3); plt.plot(x, y[:, 2], 'b+:', linewidth=1.5, markersize=8)
plt.xlabel('days'); plt.ylabel('amount (unit: Kg)'); plt.legend(['strawberry'])

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([[12, 14, 40], [20, 25, 43], [25, 30, 41], [22, 20, 35], [20, 30 ,42], [25, 30, 35], [30, 35, 38]])

plt.figure(figsize=(15, 3)); plt.suptitle('Amount of sales for 3 items')
decoration = ['g*-', 'ro--', 'b+:']; legends = ['apple', 'plum', 'strawberry']

for i in range(3):
  plt.subplot(1, 3, i+1);
  plt.plot(x, y[:, i], decoration[i], linewidth=1.5, markersize=8)
  plt.xlabel('days'); plt.ylabel('amount (unit: Kg)'); plt.legend(legends[i])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5, 6, 7])
y = np.array([[12, 14, 40], [20, 25, 43], [25, 30, 41], [22, 20, 35], [20, 30 ,42], [25, 30, 35], [30, 35, 38]])

plt.figure(figsize=(15, 8)); plt.suptitle('Amount of sales for 3 items')
decoration = ['g*-', 'ro--', 'b+:']; legends = ['apple', 'plum', 'strawberry']

for i in range(3):
  plt.subplot(2, 2, i+1);
  plt.plot(x, y[:, i], decoration[i], linewidth=1.5, markersize=8)
  plt.xlabel('days'); plt.ylabel('amount (unit: Kg)'); plt.legend(legends[i])
plt.show()
