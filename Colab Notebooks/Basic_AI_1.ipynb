# %%
import numpy as np

# %%
class Affine:
    def __init__(self, W, b):
        sel.params = (W, b)

    def forword(self, x):
        W, b = self.params
        out = x @ W + b
        return out

# %%
class Sigmoid:
    def __init__(self):
        self.params = []

    def forword(self, x):
        return 1 / (1 + np.exp(-x))

# %%
W = np.random.random([2, 4])
b = np.array([[1, 2, 3, 4]])
AL = Affine(W, b)

x0 = np.array([[3, 4]])
x1 = AL.forword(x)
print(out)

AL.params

# %%
#Test Sigmoid Layer
SG = Sigmoid()
x2 = SG.forward(x1)
print(x2)

# %%
W2 = np.random.random([4, 1])
b2 = np.array([[0]])
AL2 = Affine(W, b)
x3 = AL2.forward(x2)
print(x3)
